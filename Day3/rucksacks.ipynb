# %% [markdown]
# # --- Day 3: Rucksack Reorganization ---
#
# One Elf has the important job of loading all of the rucksacks with supplies for the jungle journey. Unfortunately, that Elf didn't quite follow the packing instructions, and so a few items now need to be rearranged.
#
# Each rucksack has two large compartments. All items of a given type are meant to go into exactly one of the two compartments. The Elf that did the packing failed to follow this rule for exactly one item type per rucksack.
#
# The Elves have made a list of all of the items currently in each rucksack (your puzzle input), but they need your help finding the errors. Every item type is identified by a single lowercase or uppercase letter (that is, a and A refer to different types of items).
#
# The list of items for each rucksack is given as characters all on a single line. A given rucksack always has the same number of items in each of its two compartments, so the first half of the characters represent items in the first compartment, while the second half of the characters represent items in the second compartment.
#
# For example, suppose you have the following list of contents from six rucksacks:
#
#     vJrwpWtwJgWrhcsFMMfFFhFp
#     jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL
#     PmmdzqPrVvPwwTWBwg
#     wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn
#     ttgJtRGJQctTZtZT
#     CrZsJsPPZsGzwwsLwLmpwMDw
#
# The first rucksack contains the items vJrwpWtwJgWrhcsFMMfFFhFp, which means its first compartment contains the items vJrwpWtwJgWr, while the second compartment contains the items hcsFMMfFFhFp. The only item type that appears in both compartments is lowercase p.
# The second rucksack's compartments contain jqHRNqRjqzjGDLGL and rsFMfFZSrLrFZsSL. The only item type that appears in both compartments is uppercase L.
# The third rucksack's compartments contain PmmdzqPrV and vPwwTWBwg; the only common item type is uppercase P.
# The fourth rucksack's compartments only share item type v.
# The fifth rucksack's compartments only share item type t.
# The sixth rucksack's compartments only share item type s.
#
# To help prioritize item rearrangement, every item type can be converted to a priority:
#
#     Lowercase item types a through z have priorities 1 through 26.
#     Uppercase item types A through Z have priorities 27 through 52.
#
# In the above example, the priority of the item type that appears in both compartments of each rucksack is 16 (p), 38 (L), 42 (P), 22 (v), 20 (t), and 19 (s); the sum of these is 157.
#
# Find the item type that appears in both compartments of each rucksack. What is the sum of the priorities of those item types?

# %% [markdown]
# ### Though process
#
# 1. Get list of strings (each string is a rucksack)
# 2. Divided list in 2 equal lists
# 3. Find common letter between those
# 4. Covert letters to priority using ASCI
#    1. a = 1, ..., z=26 ; A = 27, ..., Z = 52
#    2. x_points = ASCI(x) + 1 - ASCI(a)
#    3. X_points = ASCI(X) + 27 - ASCI(A)
# 5. Add them up

# %%
with open('rucks.txt', 'r') as f:
	rucksacks = f.read().splitlines()

# %%
priority = 0
for ruck in rucksacks:
	sack1 = ruck[0:len(ruck)//2]
	sack2 = ruck[len(ruck)//2:]

	common = list(set(sack1) & set(sack2))
	if ord(common[0]) <= ord('Z'):
		priority += ord(common[0]) + 27 - ord('A') 
	else:
		priority += ord(common[0]) + 1 - ord('a')

print(priority)
# Out:
# 7997

# %% [markdown]
# # --- Part Two ---
#
# As you finish identifying the misplaced items, the Elves come to you with another issue.
#
# For safety, the Elves are divided into groups of three. Every Elf carries a badge that identifies their group. For efficiency, within each group of three Elves, the badge is the only item type carried by all three Elves. That is, if a group's badge is item type B, then all three Elves will have item type B somewhere in their rucksack, and at most two of the Elves will be carrying any other item type.
#
# The problem is that someone forgot to put this year's updated authenticity sticker on the badges. All of the badges need to be pulled out of the rucksacks so the new authenticity stickers can be attached.
#
# Additionally, nobody wrote down which item type corresponds to each group's badges. The only way to tell which item type is the right one is by finding the one item type that is common between all three Elves in each group.
#
# Every set of three lines in your list corresponds to a single group, but each group can have a different badge item type. So, in the above example, the first group's rucksacks are the first three lines:
#
# 	vJrwpWtwJgWrhcsFMMfFFhFp
# 	jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL
# 	PmmdzqPrVvPwwTWBwg
#
# And the second group's rucksacks are the next three lines:
#
# 	wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn
# 	ttgJtRGJQctTZtZT
# 	CrZsJsPPZsGzwwsLwLmpwMDw
#
# In the first group, the only item type that appears in all three rucksacks is lowercase r; this must be their badges. In the second group, their badge item type must be Z.
#
# Priorities for these items must still be found to organize the sticker attachment efforts: here, they are 18 (r) for the first group and 52 (Z) for the second group. The sum of these is 70.
#
# Find the item type that corresponds to the badges of each three-Elf group. What is the sum of the priorities of those item types?

# %%
# Check if rucks.txt is divisible by 3
len(rucksacks) % 3 == 0
# Out:
# True

# %%
priority = 0
for i in range(0, len(rucksacks)//3):
	sack1 = set(rucksacks[3*i])
	sack2 = set(rucksacks[3*i+1])
	sack3 = set(rucksacks[3*i+2])

	badge = list(sack1 & sack2 & sack3)[0]
	if ord(badge) <= ord('Z'):
		priority += ord(badge) + 27 - ord('A')
	else:
		priority += ord(badge) + 1 - ord('a')

print(priority)
# Out:
# 0 lvcNpRHDCnTLCJlL
# 1 RFZggsMrjTFGCJmdmd
# 2 srsBZgBqwBqRZbzqtHpzzDNtHDqV
# 3 CCTPpCvlpzzZQQQflrzbQDttTJcgcggJcHtcddtdhT
# 4 nMLBRnGsFFLznRFRLMMNBnNLDRDdhScJccctdSccJJgDDHhH
# 5 GVBGVBsLjsrrvfzpjpfQ
# 6 dzVRSPVVBVDSPzDBQVSQFFlrclMplpMJMtPJlJvHZCMt
# 7 TjmGmbhjTnTmwhmrvvrHcZvCHZMl
# 8 fnLwwqfwfqjghHwGThwfTGGBFVDFFsszSRVzRBsdBDgFsV
# 9 CCWFCcdDWwcWFpSvggnzRRQszngJwT
# 10 mGtqqLrqfmmLNtNrgTjgJzNQlvJTvznJ
# 11 tnhVbhMLLZZrnWHPSHDBWbWBFd
# 12 nQhvgnCQjSSSTTSMCsLDsfPfDlsPJMWLzL
# 13 qrqBFFBbrVRLszLfsqdqPW
# 14 bNFFRbBcFZNrZRRRbprNpFrHSwznTnvSwgHvzCSSSjnCQwgz
# 15 tnnZZVmwmqtvVdZqnddQQHHTHQLsFTnsPrrgrQ
# 16 MzMflMGpzGzPGPgjLgHrGj
# 17 zPfhMJDDMJfzlhcRJvVwcVtwVcmcbqqtbv
# 18 GVzrBVcPVfGrzVVBcQJlGGRCZSSRtSdRnGLJ
# 19 wbjvHWbLvhFppjZdtwZRNddtJwlR
# 20 pvMmbpFFbqqqvWHMFvzrLDMMrMTTrVTPzVzc
# 21 qPmgpmwpwqWWPHdjdTNStzNLMztSWtMNtz
# 22 lVFfJrFJbbcsvcRVRZzQCzQNSZTZ
# 23 DGbvFSDGbDjnqgjwmGdq
# 24 DMnpnpwwnpmRRmcRBDnDwpbRQHssHqhHCHHSsQddHZQQcqqs
# 25 JlZjjlJgNSddfsgQdf
# 26 GvrWvzNjvPVLDpbPZwBP
# 27 drQDzHsHrdZWqDSSPwmmJDDbvbSJ
# 28 hphBhCMFlBtBtGTJMJsscPwTjMJv
# 29 tlBCGFgVFNpGClFFVGGtFBZrdZQznfdQQrRWVRQdRsVf
# 30 NjdCLdjzzlNdjwBBtZqpqPJQbN
# 31 CsDWcHcGHtcBbJPpbP
# 32 mGHSssSgSsHFSgGrSgmlLzCdldllrCVCLdnfnT
# 33 rDLLzRmbcLJRtRSvSBdZtSTp
# 34 MFswshwgsCsjghgFBsGssjlZpfpvdSHfTdCZTSpHtfddTH
# 35 llwlwGjMPMQQnBMswsFgglPVcWcDcbWqLWbbLJVDzrqnVr
# 36 pqmmcSTLfSSSMFlf
# 37 rHWtPWnHtlrlDntzWwtBFdzCFMRCfjRQFfgMRMjC
# 38 PWWHDVZPDDJVlWHncGGbqqTVvVmpGTmm
# 39 wLBtWhGWJBdMmZMs
# 40 jgvNCFvvGppGnmNJ
# 41 DDRQTgcvjTPFqGHhRVhLRSVL
# 42 tPPwLpBpDpgLSPvgQCvsLPjdjNZrJZsdZjsrsnZNjbZc
# 43 lMWzWMBhmMhRGfVRffHmMjJcJjrNNZnjJcWjNqJnZJ
# 44 mFMzhTmBGfHTwgPgtptFpPgP
# 45 qCcqJQHslgtsQsCZmPWNSRNZTPBBCN
# 46 nnLpjjnvwwvDnrGwFvbFjwPgPWRTPrrPShNhmmNSRRPN
# 47 bnwdDLjnzGgvFqdJQcqVfQVqHt
# 48 DfCzDCCTDLDBCsdjzwdrHjbRgjGH
# 49 MSStMScccJtPptJNJZtJJSrFdwPGjFFHHwsggrwdwRdP
# 50 nStlpVlhhNSshZlcNZnMcctpBChWBQLqCWqmqvmBCBmQBqmL
# 51 RfLHNvfLfLZQBtRZsBfffjVqGvqpGSmJpgrJpjGjrp
# 52 FDbPCMzbTTDDPmzrVzqppJBrBj
# 53 DPcWPWDhlbCcWBsQZZfHtdwf
# 54 fbHfPfHHfPZWgZfSGpqNBqdBBjpjdPBJqv
# 55 rnVNCwwrhhDrmmvcmjdDqcmB
# 56 hFRrslFRNhFzVthllRCRCCwnQtSGfQgZZbbSWQLSSTZWbQTt
# 57 nmVqTFCmTVbnvVCnqwFrffjhZLffhNrNJF
# 58 StBHWDgMBpHMBHDzLjffjWwZJNNfNZjL
# 59 wBBcDcgzdVbbQcnQlq
# 60 MfGCtqGDhjDqHhrjGCcJZZBwHRcspZsBsHRc
# 61 PFFpLFSpzVdSTPgnzzdPPZBRcZBwBJRcWJBmJW
# 62 vdTTzVpNVpfCChMGqMvr
# 63 VtZzBzhtlrhznFlBfgrfZgFrPjGRMGjRTmSjRjRTHjfRHmRv
# 64 DQpnsbJCsNNnpNNJsDQdCDcRmHPGTHTHRSmRmHjvjHSpSS
# 65 cQbnQdNLdJJQJJJDJWnFwzgwBthrgZBwBgFLZV
# 66 VhRRgmhpFjFFBDVPGPWQPzvvMMWfjf
# 67 qcnbnCbfLqJrCnrcdbbLrGSlzWsQvsWWzvWGdMWGQl
# 68 bnfbwrcwCrHqnHcZhFBTBVRDFmpBHB
# 69 lrtqltJJJqSTWJqVHRnsRhphdbfbzBdhsRsd
# 70 vSZCgZMMLSNvCQLPLDPNgZgnznzBfsGGnQnQGdnsfhsfzb
# 71 CMFLgmPgFFNMFDDCgLLcrWrjTTjtmSJqlWTTwWSr
# 72 LdjljBdZMFdZFLLLgPvWzQRzCsCmCVssmFSW
# 73 TJttwDhnnTlWsQzSQQDvWm
# 74 HtcnfctJwtwrHhrwhfHhJpjNLMZBMgZLrBlbbLNPNj
# 75 qqhNchPdpqTTNqpDmmvvGzVfzfmvdH
# 76 cwccjsFwFjnwGwQDfVVVVv
# 77 FbWjcRsLLFngBrjpbJqCJZTbJZNClq
# 78 lhznMTSzSnjhQGtVPQBdGB
# 79 msfNDDJLWslJgfNgCrmLdtGQFVvdGQPZVttBFP
# 80 RCrJJJDrJRsfgmbsrNsrlDMTSMHcjqwzScjMqqTjbbSc
# 81 nNgsvNWDRvgnRNVCFddTNZTNZQCTFZ
# 82 lffHJfHSPmSfvLlbLmpZrCTFTtrTQHqtTrCCrq
# 83 cpzblplpbvMzWnsDDB
# 84 CgtvQvJvMtWttvwftCdWvDQrfsFcrqnlcnqZZFRcRqsnhF
# 85 HzLzVBNLjHqnhzFlWFlr
# 86 NmBjLbVVbmbTLpTjBNVLHNdCtTSWQvCgdwSwJtWQwdSD
# 87 lncHcnlccVSLNSQNslncLcrZJCrgPfJZDrggJCCvZPHC
# 88 jRqqRmmqFwRFppfPPppPBfpWBvZf
# 89 wmMqjtTdjFwGGdtNhQbVfhntcNLVbL
# 90 HFBgMjpbpddMpbHdgHLLRNwhwFLDtNSRDLLD
# 91 zsCnfqZflrlnhhrtwNgggNNL
# 92 CGqnQzlqlWWMWgVBGg
# 93 pQnvzjztpzpCmtzzjzpnBHrJNGlqggMMqgqlNWgfNNqNCP
# 94 sVTSwddRRDVShwRwRTWgPNqMGQMGNqMWslsg
# 95 hDSTQhcQcHrtcBmZHv
# 96 QRmQfvQpWpswfZWWvNbhlMglgFbZDldlbL
# 97 rzHqtcnqqVjqjGcHdLdFdCFdCbLDnMCh
# 98 DGcGGSPDpWTsSfpv
# 99 llfMHTmvHlfZlFZRzgQzsFBLtLzFGF
# 100 wrWNJrdJhRmhGmNh
# 101 DWrrJjwPjCdPDwdmwnrTZnZZcqZfnqbvZfHvql
# 102 mPmVJJmNZJmlVBPPrZpWcFWbGWbjgqNbdqjSjg
# 103 nMhzwRhwvhMDMgWHRdGHgccggd
# 104 sMvnhQshMwwvdvMMCwBtlZtplZpTmPBVZVlC
# 105 ltlRzpncRglplzhFwFwzZZMWLWZBqnDVZLDVZQQQ
# 106 SJcdvJscNSsGcSGCSJmsTQDTVZQTLTQQWCTTMQCW
# 107 sPdJmcvsJvGJmdJmfpwftfrlztrRlPfP
# 108 LdPrWcMCWCfPdMJgdFsbRRHsRSHRHHcFpH
# 109 hVVTQmQTnRFLFsmzps
# 110 qthVVwZqlQLQhNttDDDWrffDJJJDrgNP
# 111 BTjTNjtlPrBjjrljbnMFfhVWFFhlMWMfHdll
# 112 mzcgZvDggDDCJCZLvsLJLcmVqWVSVqFLfdHHMWVWWWffnF
# 113 cmmcmzQDZQJmZCnDRgQCTTwjpTtwRjrbNjpPpwrj
# 114 rMbchQphhCSbGnzSbl
# 115 qFtgvTTqFFFFJGzWJG
# 116 NZjGqGBNjNHQrhpPNHQr
# 117 LnLmbtTtTwtLcVfFFLtPrfPrfqqqsqhSvrhrhh
# 118 BzJWzZRZJzJvlZJCZgZZpJHCqQDhNQPDqDDrjNsjPPNrhSCN
# 119 lpJWZzJpgHWdWMgHlJMZzgpJLGVLGGvwVwtmcGbvGMGVvncn
# 120 WdBgdqRgWqHmNNwsGgcQ
# 121 ptPVbPbSbMJrmsVzRzhwmcGQ
# 122 SSbvrJbJtCDZfTqdRfCdBZ
# 123 WDNNWvPpvNJRRbGLsGMnnbmG
# 124 qgFdBwgVdjwdtjjdBgMgGmLQsnZrnZssGswsmLrw
# 125 FqTCTtqjdjVqgCqSMJMTvPThTJMNDh
# 126 brSSSpZjVVWdfVrHPhRBggNNGwHr
# 127 fDlLzFCLMvnMMJLNHNCBQwNhRgwRPP
# 128 MJqMmfzDvFtLDtmsVsZZTsSScWcsbq
# 129 CSZlllhSdnDrrDdJjqjzbSGzGvwbfHMb
# 130 gTNvVNLQtsFpQHqfwfBfVMfHzf
# 131 QgNmWTtmTcmmdmrZRvnlPl
# 132 SmzfvfjvjbjLNJjD
# 133 cFhWMhGHTPhccMQQGBTFGwbVVwdbddJDvVJLvDDHvd
# 134 GFMBGcWTWhcGrhFZTTchQsSfgtmnnRvnmnnRgRCrRS
# 135 ZTQHVZsZSQpQQGBMGqfBRbRB
# 136 CwtLDtNFcPnllwnqvMgbvGVfVfBG
# 137 VClLWWFPPhlhctsTrrSpWpmszjZj
# 138 HChzPltNnnHtnpqSpHpFpSfSvS
# 139 mJmQssZJLdTQLcbjlGLGfSgMbqwwSFSMSFMMqMwS
# 140 JdBLlGTjLjjjjdmmBPnRzCBRNPhPtPWPtr
# 141 FPLHMHqqPMgFLLggsMghTJhwtDSSJDltJvtwdvST
# 142 WQfmjQZsjfZNQCrZCNZQQWQBCSClvdwTSClwSwlTJvtwJdbT
# 143 BpmzrWcpBrfmpsGPGFqPRgzqVPLM
# 144 bHjccpHwGHJTfPlffPwr
# 145 VtChMZVhhStZdfTCfJvcPRCTJn
# 146 sLNLZcdNZZqZqqVqSNWtjQDGHssHGHgQHDBgmsDg
# 147 CdWgCpddwgClFlmmVTBbRtRtbntBVVds
# 148 vcJGhPLPhJvChLhMLfccrvfvsVVbsGBTTBnVbRzBVstsGnbz
# 149 vJJHhjcCLPPjQPHLrSZmpgmqwlWZZgZZQm
# 150 VpTFCFtrjCdJdjHVFnSjszSllDjsDzgvzl
# 151 fhmhZBMtfZfGBNfNcmsbZnzSlRsRggslsbnv
# 152 qPLPhMcLhPfNWPpFrdFdFTtJ
# 153 nlgQJhJFlncMzMWZMFvw
# 154 mDdsDfHjHsjHdjTLfpDsbDcNzzwcRbZNZPMcCPWMRPMc
# 155 sqqdwffHjTmdmpffmLddTTGDnSJtJBShVVhrGVJtShrlBBnJ
# 156 CrcMcMDBCmLlZdSd
# 157 qPjGjnQPqWjgZmTdlFwTmqLJ
# 158 bnPnnzHjbPznzVpdpVDcvprr
# 159 TCScMQcQCrssJPQhQs
# 160 VpfnqqfdVVwpqvqwGbDPPsjgPShDSsJhlnSl
# 161 qffdmGpfwfbfvVqpfwwfbdqRMTSTWNMWTmZLTzTCZTMLWC
# 162 QQPpPbPbDNplSJrCCj
# 163 VdMzffgnRmVdfVWRvlrCTjRlNBvrrlrr
# 164 mGgNdthhGgMWWtsFcHcHwqLqtH
# 165 HrPFVqVppVpDjFDrVbCpDFJSLsmwjhjGLLmthJLJLmZs
# 166 WWgRdMdRMnQnRzWvPSssPWssJmhsshtG
# 167 MnfvMlnQccvfMlcTRMQdRfpHPDDDpPrDTbTBNbHbHDCq
# 168 GWWRsSwLhWsRsSbsPttThZqrNBJJBgPNCJCCqNMNgP
# 169 HpVDTHzfFDpFfzHzFVcrBZCggMJBvNrNgcNNrM
# 170 jlVpVpVVQDHdFVlmmmQTlzpjjGstWLsSbsnnnStWLRhnht
# 171 prLMDDjNCLZbdFLGngdLBv
# 172 VQHmhWSSzhWHmPJRJhSmVHJPFvgTbtnTbBtGqbQnbdqgTFqG
# 173 RzwzzhwhwNCvvfpc
# 174 wQgmZnhmWVtwQmnnnQbQhzwsFcRPrFPvRJhPlPPBBBFvJv
# 175 DdjqMMGLLMMGqTGdMqdMLdBBJsJPJBJJrrBFcqRlPlqr
# 176 DsddsfMsWgfzftZb
# 177 lcqlFSFwBBPlNwPlvSlQfWsVLTQjzjWVfLsWVq
# 178 HMMbMHMtJHgFzzFrVVtfFQ
# 179 RMFpCDDFcCNBcZvP
# 180 gwDrClhppDDPwPhnmPlwDrlDjMFfMTjMTjJmRHHJBJRMJHGj
# 181 LbbZBSvSLVRHffHJHJGZ
# 182 WztdtLsSvNQStbbtzdStthWhnwnPBDclgwwnrwllCC
# 183 MnMMBppMBDWMhpnCDBgCBmRbstvPvvbGltSPVGlVPWVv
# 184 TrrddJHjNcTqrrqdFcqZwSvLSlGGPbtFRbLvFVSRPG
# 185 JTccqTcwNQcTJrZwNJcJqHwJBQDfhCBCpCQpmpDfMRfCfBpn
# 186 njVcjHfGjVjpTCpMWprW
# 187 tsSsQDvSqQshDhtmWpnQnmMmbrpdzM
# 188 FNhsDDLNLnNllBqfRJGBVHBPHRRBZZ
# 189 hFVdlFSFlfZdRhgWgdWnnnfGpMNfnLMQzQQjMD
# 190 RsrJRHsvBcvHBHjDMMpDQDjjzDHj
# 191 BcCmBqvrbbqJgmFZtWdRVSVV
# 192 FzzdDJrJCFSFRqLlwsgspsBCpL
# 193 HQdWhMZMVwqLMllw
# 194 bbQtcvZcmHtNPZcWthWRvrdrRzrSDfRSrzjJjR
# 195 bTFZzHjZNJHzLggsJgbdsWcdcShWCwsSSdvGvv
# 196 VDBmntntfCBGGGGhRc
# 197 fMnnPDfmDlmnMPmtmttnVlHzZzNLbFbLbhzJJjMgJFbb
# 198 GzgJGPRrMSgTgpgH
# 199 hcvWhBdhcfPFvmFQvwfbHMsMMbpDpTDSSHsHpd
# 200 LmcvFFlcWQlFlfPnRZPVCJzJClCz
# 201 DdCHCHrmHRgghTHH
# 202 pFVZFwfssMsgghML
# 203 tSnphvhtctSSQNDqNdmrWGvq
# 204 rqmtRmGmcWrRRQprRRnfbGMMlPGGPblwMbTP
# 205 BHHhVZSvDNdhvBVhshbzfPbTmDfnwPwzPgbl
# 206 ddvBsSSdsLdshLsLpmWqcWrCCrtFpQ
# 207 wZPCwdPCHrnLQCGZDcPRqllzqqBzjlqc
# 208 gMmgnJspsvTmWNVWNpTNWNcDcqVjqDcclhSzllRSDzqR
# 209 JnWsgMnngmttFWWMdrwCZwHfZfdfGdFd
# 210 wwgNgrsWvbfBrqqsWbjDCDDDCDCmFbSmLDLlSC
# 211 QdpdzQTVdzRMTVVzcHTQLnlFmZHPSChCmlDPPHnP
# 212 dRMLVttzzVtTVQVqrrrgBtsvWWwtNw
# 213 vtBvntlqMvfnTfPDPhdRNbhdTFzF
# 214 QLWcmrrcgmCgCcsgcQWlWWrrDjjzzjsdFDdRhPNDhhhzDzPF
# 215 GGWHcCQcCCSlmmBVMGVBfMqwJtqv
# 216 cfqfhDRwhqZgRgRzRvcfhBSrsBnrDBBJWrnrWrSmmr
# 217 VCTVjGCTCjFddQntmrsVsJvrtrrW
# 218 PFQGpFbvPRMNqgRq
# 219 MmDgZZGMjZGfZRFztzCtCjzSrF
# 220 cBNpPJpBdNntcBHBccJlsSVVzzSwlCRrCnzsFw
# 221 PPBJLPPBBLPHBNQgqfMQtmTftGGvhq
# 222 bbZnbnVVgVSnbgZtntZrltsprpMCJvpqdJmsCMMmvvCq
# 223 BjDcjLLDzNjLDcjDzhcDNLLLHdpmpHJsqsMMNfCHfJpspqvp
# 224 dFLTFBcBzjFLgTbQtRgTVTlZ
# 225 nqNnrBRjLnjLZCqGGlqSGWlWDS
# 226 mTJTTcTJJfJfhhhwMbQDPWCQFCRlbDCSDDPl
# 227 dhMcRgJmgRrBrrrNgrLZ
# 228 GvJvJSGZFrGmmbmCrWnhjncLctcWttVqjLBB
# 229 wDlTzwlHTncRTqnRBt
# 230 gspglgzDzdPDfpgfdDzsgMPGvZJBrrbZGJNFmCFvmFvFvM
# 231 RLjMZZzfvNLBdjQfBfQdhRfSTVlcVqGbGcLGlbmqLVccmm
# 232 FggHCwsggrWWtCHJDDHtWrTNNlqSnlTlnGVTmWGcbcbm
# 233 PtpttrwsJssPsdRQvphZNzdMBh
# 234 NqqpZBHqTBpPNpPpGwwMPGTJjjLjQljGmtLfftllbJQfGf
# 235 nHczcrSFnVWSlrltrgJmjLLQ
# 236 SvzcDDVVFzdzhndCFSvnhcDspRDRDMPpMHRNPPZqppwM
# 237 FRSbVCSFFCDMFjRMjSSVFSWggMmWtWngJWttWmmJctnt
# 238 BPwcQQcQqQmWHfgrfwrh
# 239 PPlBQdNQvdLzzvclczdNRSbpLSbRbDjFZFFZVsFs
# 240 wtrrVhBbpcZSSjBfSfmm
# 241 MDWTvTMGMRCDCTQWsvfrRjjFfHlFmjlmLlHl
# 242 gQrTQvQDssdNWGsTstcbptwVPqcbpNqttP
# 243 jtGSwGQczrzjtGzrcsJwMRqMVMwRVMWFvVTWFV
# 244 DhLgnDLndDHmLvWqpTHqHHVNqF
# 245 LhdmPhfgZnZDlPCPmDfljQtGsJtBsWjGJzJSWBjC
# 246 zHDjcjBjTfjjfGpf
# 247 NNFTnNwPNNdqnJdFnqqTgmgftfftrWCZGbmrpWttmW
# 248 FLJqVNVNhnwnTRsRQBlQzShs
# 249 HJGJGJzzHHQHfJHsnNsGMbccMrTgbr
# 250 vddSCCjdmVvDDmvmBVbbBchcrrcscMTTnscn
# 251 VjWdFCVVMWWmjdSVFSVpqwwZttfJJltJZqltppLw
# 252 SnmPBPBnMLnPBsSgSDqRNRRccDfNcNQQRg
# 253 lZVWtWVzCjvZzCCGzDwbwRwtqJwJNTtDfD
# 254 zCzHZFFFfdLnBfFf
# 255 NRBFpNNJgNbWbJLRpRbWNtNpZllCZdjjZfjPVljTVCZQltlV
# 256 sDqHmsHcDrwHhMDlfCQfVBjDPCTd
# 257 MnGGcqwhhsrchcmGpzRJSSGGJWJzbJBR
# 258 LBzjQQzcjWvHWLnVDdnHRffHDCVR
# 259 rmJSrPJJsbNZssGSPrFpddfGwDRRpVjVpCGdCp
# 260 mPsrmsNTrPNLTjQlWQhqLc
# 261 MSDFszbhbRRTRdwhtw
# 262 PWmCZCmZVvGqMcjmJRpdTTtdLpqwdlll
# 263 MWGmmCVHvMSBDSNbbHHS
# 264 mBwSBSfSPHZCLPZSWwfPppTndVpdVncFgcgPpP
# 265 rhQJjzQjrltJzGqCrGJTvgqRpnTgFgcFTVFqFR
# 266 QbhGMJrhzrhQGQCsjwMDNWBDSZBZwSBLmM
# 267 bQfDPgDQbQNGPgflWfvMZcRMMFmcvMfZ
# 268 BLqSssjnzpBwszqwzFCNMvzWvRvzCCZFvc
# 269 BpNpjnNHnSpssqLqrBLLHjdhTPPDgbggllldhTPdrrQh
# 270 CvCMqNWVVqqPvNvvChhhdSnFHwBdWwhfdS
# 271 gqTZGGjlmclrZjlmSndSDwfFhhDBHm
# 272 tRrZpgrcctbbltRpgtqCVJCvPsRvsvPCQPCLPz
# 273 dTjRdWDBRzvjfzTfvTJPtJttsSLqHsSQJw
# 274 hrJNmbnFNZrbhlCsqltqcQcQSQqwPL
# 275 pVNhFgZphZmjzvjGDJWzVJ
# 276 gWzQhCWbQnCCFgCJnFQnWCzwjrHjjHGTwHGrhLwjjjtStL
# 277 splcpqDNDqqcZqRlspwHbjVrjjHTrwSbtVNV
# 278 BpMslDqDmRDRsBRBJPPnbzCfvQgmCWJb
# 279 tRtgRQWCwlTglHZHTglCtTdbbfvhWpbSBbhWzzbfGpfhbb
# 280 cqZVMJmLqmNrsJMDbzGrGSvzGBhvvG
# 281 mmnJPMZcclFRdnQtCQ
# 282 QVQVqfFzVVQQrQwZsCTrBtTrccTtctcJRRjT
# 283 vNNPnvGbBtWBLvBf
# 284 mMHbfDfHdHGmnhDDqZFDzVSQzF
# 285 NNlTNFCRTrfllTZsPWSsFPfzJdVQVpDQVszQVtpbzJMVbJ
# 286 LNHjNHjmLLjNqvGgvVQJQDVLbDVDpdQQzQ
# 287 nqmqGHjwgHvgwGHjGgccNTSWrrlCZrFfPSFFCP
# 288 qWzCQqhPCHjHmqJhqvqmjRgSFMTFggMFTFVRVVTgTm
# 289 SptGsDlnGfnDLgTMTwgRFFFs
# 290 bBcntZdpGZZcctlGtDfnDnBCSWqJvQhqjqzjhJqJQCQWPd
# 291 SjZJrSSDShddqLvPqzzdwq
# 292 nTssfRpQQmQCHlPBBgGmwVGzwm
# 293 TWQsbCRQFHFWQRTpzRHRsRrMtDrjhjbtMbccrttJjJht
# 294 cCChVMwPPMHCPCCPrvJnntdTJSvTtdrSRt
# 295 FGfFDBhGGlfGGfWJWdbSRSnRNbTvdn
# 296 fGpGlDmBhflgfDFmmfFpcVzMzqZZzcCPQVZzqP
# 297 SmgtSjGPjppBjbqqWTCZDQTHHHTg
# 298 VsFfCzLvsMfzNfNRhVMslzlHqrWrQDQcqDqTrLWHcrWJJW
# 299 dsRdsNCvNMVpwPdnnGbbPb
